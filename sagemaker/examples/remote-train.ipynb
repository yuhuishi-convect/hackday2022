# %%
# S3 prefix
prefix = "DEMO-convect-byo"

# Define IAM role
import boto3
import re

import os
import numpy as np
import pandas as pd

# role = get_execution_role()
role = "arn:aws:iam::932478379847:role/service-role/AmazonSageMaker-ExecutionRole-20210820T133633"

print(role)
# Out:
# arn:aws:iam::932478379847:role/service-role/AmazonSageMaker-ExecutionRole-20210820T133633

# %%
import sagemaker as sage
from time import gmtime, strftime

# %%
sess = sage.Session()

# %%
bucket = sess.default_bucket()

print(bucket)
# Out:
# sagemaker-us-west-2-932478379847

# %% [markdown]
# # Upload data

# %%
WORK_DIRECTORY = "../../tests/data/"

data_location = sess.upload_data(WORK_DIRECTORY, key_prefix=prefix)

# %%
config_str = """
ml_sum_model:
  cv_param:
    split_train_frac: 0.8
    split_type: time_split
    train_folder_cnt: 3
  dt_feature_extraction_params:
    - feature_name: isoweekday
    - feature_name: is_workday_CN
  encoder_param:
    autoOneHotThreshold: 5
  impute_param:
    fill_value: 0
    strategy: constant
  main_ts_rolling_params:
    - rolling_method: mean
      size:
        - 1
        - 3
        - 5
        - 7
    - rolling_method: lag
      size:
        - 7
        - 14
    - rolling_method: std
      size:
        - 3
        - 5
        - 7
  ml_model_params:
    - method_ind: lgb
      param_opt_ind: random
      param_model:
        objective: tweedie
        tweedie_variance_power: 1.4
  model_select_method: manual
  model_select_param:
    metrics_funcs:
      - mae
    only_use_out_sample: true
  other_ts_rolling_params:
    - rolling_method: mean
      size:
        - 1
        - 7
        - 14
  scaler_param:
    scaler_method: MaxAbs
  train_expand_param:
    - long_jump_interval_list: [30, 60, 90]
      num_short_jumps: 6
      short_jump_interval: 7
  ts_window_param:
    time_window: 60
predict_target_params:
  - predict_horizon: 7
    predict_offset: 0
quantile_model_alpha_params:
  - 0.1
run_ml_quantile_model: false
"""

# beacuase the config string is too long, we cannot pass it as a hyper parameter
sess.upload_string_as_file_body(config_str, bucket, prefix + "/config.yaml")
# Out:
# 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/config.yaml'

# %%
# !ls {WORK_DIRECTORY}
# Out:
# cate_info.csv  stock_ts.csv  target_ts.csv

# %%
# !aws s3 ls {bucket}/{prefix} --recursive
# Out:
# 2021-08-22 22:35:35       2060 DEMO-convect-byo/cate_info.csv
# 2021-08-22 22:50:05       1254 DEMO-convect-byo/config.yaml
# 2021-08-22 18:06:01       2629 DEMO-convect-byo/predict-payload.json
# 2021-08-22 22:35:34    1004419 DEMO-convect-byo/stock_ts.csv
# 2021-08-22 22:35:33    1020803 DEMO-convect-byo/target_ts.csv

# %%
# Estimator and fit


account = sess.boto_session.client("sts").get_caller_identity()["Account"]
region = sess.boto_session.region_name
image = "{}.dkr.ecr.{}.amazonaws.com/sagemaker-algoflow:latest".format(account, region)

algo = sage.estimator.Estimator(
    image,
    role,
    1,
    "ml.m4.xlarge",
    output_path="s3://{}/byo-algoflow/output".format(sess.default_bucket()),
    sagemaker_session=sess,
)

# %%
# set the hyperparameters
algo.set_hyperparameters(
    time_col="date",
    key_col="item_id",
    value_col="sales",
)

# %%
algo.fit({
    "target_ts": "s3://{}/{}/target_ts.csv".format(bucket, prefix),
    "item_meta": "s3://{}/{}/cate_info.csv".format(bucket, prefix),
    "related_ts": "s3://{}/{}/stock_ts.csv".format(bucket, prefix),
    "config": "s3://{}/{}/config.yaml".format(bucket, prefix)
})
# Out:
# 2021-08-23 05:59:20 Starting - Starting the training job...
# 2021-08-23 05:59:43 Starting - Launching requested ML instancesProfilerReport-1629698359: InProgress
# ......
# 2021-08-23 06:00:46 Starting - Preparing the instances for training......
# 2021-08-23 06:01:54 Downloading - Downloading input data
# 2021-08-23 06:01:54 Training - Downloading the training image.........
# 2021-08-23 06:03:27 Training - Training image download completed. Training in progress...Starting the training.
# ("Training params: {'value_col': 'sales', 'key_col': 'item_id', 'time_col': "
#  "'date'}")
# ("Schemas generated: [{'type': 'TARGET_TIME_SERIES', 'path': "
#  "'/opt/ml/input/data/target_ts/target_ts.csv', 'format': 'csv', 'schema': "
#  "{'key': ['item_id'], 'time': 'date', 'values': ['sales']}}, {'type': "
#  "'ITEM_METADATA', 'path': '/opt/ml/input/data/item_meta/cate_info.csv', "
#  "'format': 'csv', 'schema': {'key': ['item_id']}}, {'type': "
#  "'RELATED_TIME_SERIES', 'path': '/opt/ml/input/data/related_ts/stock_ts.csv', "
#  "'format': 'csv', 'schema': {'key': ['item_id'], 'time': 'date'}}]")
# Temp schema file: /tmp/tmptnthq6u9
# Start preparing the data
# 2021-08-23 06:03:31 INFO algoflow.app.forecast.cli.run_forecast   Reading schema file from /tmp/tmptnthq6u9 ...
# 2021-08-23 06:03:31 INFO algoflow.app.forecast.cli.run_forecast   Scheduler address is not given, will use LocalCluster ...
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.cli.run_forecast   run_forecast with run_id=run_id_1629698615-4a94 workspace=~/.algoflow
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.automl.api         Starting data merge. (target_ts_file={'format': 'csv', 'path': '/opt/ml/input/data/target_ts/target_ts.csv', 'schema': {'key': ['item_id'], 'time': 'date', 'values': ['sales']}, 'type': 'TARGET_TIME_SERIES'}, related_ts_files=[{'format': 'csv', 'path': '/opt/ml/input/data/related_ts/stock_ts.csv', 'schema': {'key': ['item_id'], 'time': 'date'}, 'type': 'RELATED_TIME_SERIES'}], item_metadata_files=[{'format': 'csv', 'path': '/opt/ml/input/data/item_meta/cate_info.csv', 'schema': {'key': ['item_id']}, 'type': 'ITEM_METADATA'}], output_path=/tmp/tmpijz7t_cz, data_frequency=day)
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.automl.api         Tasks fired with client
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.cli.run_forecast   Converted dataset will be saved at: /tmp/tmpijz7t_cz
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.lib.data_loader.load convert_raw_data_partition_cnt:4
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'sales'], dtype='object')
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'stock'], dtype='object')
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'cate1', 'cate2', 'cate3'], dtype='object')
# 2021-08-23 06:03:35 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:03:36 INFO algoflow.app.forecast.lib.data_loader.load Estimated number of partitions: 1
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  save data to /tmp/tmpijz7t_cz
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:1.32 kB as pickle file to /tmp/tmpijz7t_cz/__TASK__
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-9587ed8f9c50c7d58b3f1ce60022278c/b5fe79a357db803b6d7bbb766b39189b
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-04e586941d09d90cdf924b65d6d9022c/4e9fc0439f6beb7cde07717a2041cf1f
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-bd0903c46dedb256829b818274ab0d75/cb0e4af162303630af808f79c590afc5
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-3cf79d07ec0b6dbbc17824f748aca90e/8a4922e4f0f043cb651fde7bcb209cd6
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-c88faea8f8d761d17e537a2d895335cb/9d59948588dca3cacf2f2a54c565ecc7
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:14.57 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-fa6eed39d24cf93bce3059f9924edbcc/65c3337b7ab3c110b2880f1035131b04
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:2.72 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-a6e1132e8d458e1e4f3f940f35774720/f0039feabe9722b35cdd88a844a8c457
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:600.72 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-a162bb87875ef4dd08bc84a2c186acb9/c433540a95d6e0d2d16d4fab0102e5f8
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:13.07 kB as pickle file to /tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:37 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /tmp/tmpijz7t_cz/__SUCCESS__
# 2021-08-23 06:03:42 INFO algoflow.app.forecast.cli.run_forecast   Scheduler address is not given, will use LocalCluster ...
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.cli.run_forecast   run_forecast with run_id=fit-run workspace=/opt/ml/model
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  load data from /tmp/tmpijz7t_cz
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__SUCCESS__
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__TASK__
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:46 INFO algoflow.core.api                        Create Algo dag
# /usr/local/lib/python3.7/site-packages/omegaconf/basecontainer.py:232: UserWarning: cfg.pretty() is deprecated and will be removed in a future version.
# Use OmegaConf.to_yaml(cfg)
#
#   category=UserWarning,
# 2021-08-23 06:03:46 INFO algoflow.core.api                        AutoML config:
#  ml_sum_model:
#   cv_param:
#     split_train_frac: 0.8
#     split_type: time_split
#     train_folder_cnt: 3
#   dt_feature_extraction_params:
#   - feature_name: isoweekday
#   - feature_name: is_workday_CN
#   encoder_param:
#     autoOneHotThreshold: 5
#   impute_param:
#     fill_value: 0
#     strategy: constant
#   main_ts_rolling_params:
#   - rolling_method: mean
#     size:
#     - 1
#     - 3
#     - 5
#     - 7
#   - rolling_method: lag
#     size:
#     - 7
#     - 14
#   - rolling_method: std
#     size:
#     - 3
#     - 5
#     - 7
#   ml_model_params:
#   - method_ind: lgb
#     param_opt_ind: random
#     param_model:
#       objective: tweedie
#       tweedie_variance_power: 1.4
#   model_select_method: manual
#   model_select_param:
#     metrics_funcs:
#     - mae
#     only_use_out_sample: true
#   other_ts_rolling_params:
#   - rolling_method: mean
#     size:
#     - 1
#     - 7
#     - 14
#   scaler_param:
#     scaler_method: MaxAbs
#   train_expand_param:
#   - long_jump_interval_list:
#     - 30
#     - 60
#     - 90
#     num_short_jumps: 6
#     short_jump_interval: 7
#   ts_window_param:
#     time_window: 60
# predict_target_params:
# - predict_horizon: 7
#   predict_offset: 0
# quantile_model_alpha_params:
# - 0.1
# run_ml_quantile_model: false
#
# 2021-08-23 06:03:46 INFO algoflow.core.api                        AutoML meta:
#  {'raw_data': <algoflow.core.datamodel.Data object at 0x7febf0727dd0>}
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-04e586941d09d90cdf924b65d6d9022c/4e9fc0439f6beb7cde07717a2041cf1f
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    The time series length inferred is 360
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Infer rolling parameters for time series of length 360, horizon 7, and window size [1, 3, 5, 7]: [1, 3, 5, 7]
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Infer rolling parameters for time series of length 360, horizon 7, and window size [7, 14]: [7, 14]
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Infer rolling parameters for time series of length 360, horizon 7, and window size [3, 5, 7]: [3, 5, 7]
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Infer rolling parameters for time series of length 360, horizon 7, and window size [1, 7, 14]: [1, 7, 14]
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Infer expanding parameters for time series of length 360 and offset 7: [234, 241, 248, 255, 262, 264, 269, 271, 278, 285, 292, 294, 299, 301, 308, 315, 317, 322, 324, 329, 331, 338, 345, 352]
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.flow.default_flow Update expanding parameters for time series of length 360 and predict_offset 0 predict_horizon 7: {'expand_indexes': [234, 241, 248, 255, 262, 264, 269, 271, 278, 285, 292, 294, 299, 301, 308, 315, 317, 322, 324, 329, 331, 338, 345, 352]}
# 2021-08-23 06:03:46 INFO algoflow.app.forecast.automl.analyzer    Inferred time window span = 60
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Saved bytes size:67.40 kB as pickle file to /opt/ml/model/fit-run/__DAG__/__TASK__
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__DAG__/__SUCCESS__
# 2021-08-23 06:03:46 INFO algoflow.core.api                        Generated DAG and saved in /opt/ml/model/fit-run/__DAG__
# 2021-08-23 06:03:46 INFO algoflow.core.api                        Initialized Algo with run_id=fit-run with workspace=/opt/ml/model and save the algo dag to /opt/ml/model/fit-run/__DAG__
# 2021-08-23 06:03:46 INFO algoflow.core.api                        run fit with token=convect-fit
# 2021-08-23 06:03:46 INFO algoflow.core.api                        Create Algo training function. (dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-fit)
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__SUCCESS__
# 2021-08-23 06:03:46 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__TASK__
# 2021-08-23 06:03:46 INFO algoflow.core.api                        Loaded DAG from file /opt/ml/model/fit-run/__DAG__
# 2021-08-23 06:03:47 INFO algoflow.core.api                        Create fit func with dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-fit, check_point_path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit
# 2021-08-23 06:03:47 INFO algoflow.core.api                        Start fit process
# 2021-08-23 06:03:47 INFO algoflow.core.utils.utilities
#         N_Workers=4
#         N_Cores=4
#         CPU Use(%)=23.1%
#         Memory Use=1.06 GB
#         Bytes Stored=0 B
#
# 2021-08-23 06:03:47 INFO algoflow.core.definitions.dag            Submit dag to worker: ('tcp://127.0.0.1:41931', {'cpu': [3.8], 'memory': [261427200], 'time': [1629698626.7292655], 'read_bytes': [102569.41194984586], 'write_bytes': [102569.41194984586], 'num_fds': [22], 'bytes_stored': [0]})
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:113 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/text_feature_cols-bc2c2495/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/text_feature_cols-bc2c2495/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  load data from /tmp/tmpijz7t_cz
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:447 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-fa6eed39d24cf93bce3059f9924edbcc/65c3337b7ab3c110b2880f1035131b04
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column stock - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using SimpleImputer
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:14.58 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__LAZY_COLLECTIONS__/lazy_collection-fa6eed39d24cf93bce3059f9924edbcc/65c3337b7ab3c110b2880f1035131b04
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using SimpleImputer
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-c88faea8f8d761d17e537a2d895335cb/9d59948588dca3cacf2f2a54c565ecc7
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate1 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-04e586941d09d90cdf924b65d6d9022c/4e9fc0439f6beb7cde07717a2041cf1f
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:2.29 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-9587ed8f9c50c7d58b3f1ce60022278c/b5fe79a357db803b6d7bbb766b39189b
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using SimpleImputer
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=constant~fill_value=0~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 3 tasks
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=constant~fill_value=0~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using MaxAbsScaler
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=constant~fill_value=0~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=constant~fill_value=0~verbose=0~copy=True~add_indicator=False#MaxAbsScaler~copy=True, dtype: object
# Dask Name: rename, 15 tasks
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_sum to column Column sales#SimpleImputer~missing_values=nan~strategy=constant~fill_value=0~verbose=0~copy=True~add_indicator=False#MaxAbsScaler~copy=True - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:462 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:691 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.time_feature Extracting time feature is_workday_CN from column Column date - Type ColType.T_TIMESTAMP - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:11.76 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__LAZY_COLLECTIONS__/lazy_collection-90752e4b5196df1199343cdc884e21ae/24a07b2269e324cc9229595fa9d9da98
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.time_feature Extracting time feature isoweekday from column Column date - Type ColType.T_TIMESTAMP - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate1 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:11.76 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/lazy_collection-0ae2b65157e84abaf64163009c414000/af8c6ee54918cf93c779622395b5b765
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:2.94 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate2 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate1#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LABEL
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-bd0903c46dedb256829b818274ab0d75/cb0e4af162303630af808f79c590afc5
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:589 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:2.94 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column stock - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate1#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:731 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using MinMaxScaler
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/lazy_collection-0ae2b65157e84abaf64163009c414000/af8c6ee54918cf93c779622395b5b765
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-04e586941d09d90cdf924b65d6d9022c/4e9fc0439f6beb7cde07717a2041cf1f
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate2 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate3 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate2#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LABEL
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-3cf79d07ec0b6dbbc17824f748aca90e/8a4922e4f0f043cb651fde7bcb209cd6
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:629 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.weight Generating weight from col=sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False using target_weight_type=EQUAL
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:566 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_weight_col-b7fa2913/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:811 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate2#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate3 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:294.03 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__LAZY_COLLECTIONS__/lazy_collection-6d07ec59f17e3ae22a276ea215c588c7/917bb63dbf87cb0376bc71f68b0de131
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-fa6eed39d24cf93bce3059f9924edbcc/65c3337b7ab3c110b2880f1035131b04
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate3#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LABEL
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:709 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:26.22 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/lazy_collection-2cec023c1aaf3235df548c780fa4816f/352f4b6a3da177564d48bbea1db5c068
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:11.01 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:3.47 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_weight_col-b7fa2913/__LAZY_COLLECTIONS__/lazy_collection-3f5e583adf9be33acae34f9bab85c54d/c211d0d51e12a017d7c0078d9167cbe9
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate3#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:5.96 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:6.01 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_weight_col-b7fa2913/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_weight_col-b7fa2913/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/target_col_list-5882b094/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:608 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:820 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__TASK__
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/lazy_collection-2cec023c1aaf3235df548c780fa4816f/352f4b6a3da177564d48bbea1db5c068
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/lazy_collection-0ae2b65157e84abaf64163009c414000/af8c6ee54918cf93c779622395b5b765
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-04e586941d09d90cdf924b65d6d9022c/4e9fc0439f6beb7cde07717a2041cf1f
# 2021-08-23 06:03:47 INFO algoflow.app.forecast.automl.flow.step_func train_expand_index: [234, 241, 248, 255, 262, 264, 269, 271, 278, 285, 292, 294, 299, 301, 308, 315, 317, 322, 324, 329, 331, 338, 345, 352] (2018-08-23T00:00:00.000000000, 2018-08-30T00:00:00.000000000, 2018-09-06T00:00:00.000000000, 2018-09-13T00:00:00.000000000, 2018-09-20T00:00:00.000000000, 2018-09-22T00:00:00.000000000, 2018-09-27T00:00:00.000000000, 2018-09-29T00:00:00.000000000, 2018-10-06T00:00:00.000000000, 2018-10-13T00:00:00.000000000, 2018-10-20T00:00:00.000000000, 2018-10-22T00:00:00.000000000, 2018-10-27T00:00:00.000000000, 2018-10-29T00:00:00.000000000, 2018-11-05T00:00:00.000000000, 2018-11-12T00:00:00.000000000, 2018-11-14T00:00:00.000000000, 2018-11-19T00:00:00.000000000, 2018-11-21T00:00:00.000000000, 2018-11-26T00:00:00.000000000, 2018-11-28T00:00:00.000000000, 2018-12-05T00:00:00.000000000, 2018-12-12T00:00:00.000000000, 2018-12-19T00:00:00.000000000)
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-3cf79d07ec0b6dbbc17824f748aca90e/8a4922e4f0f043cb651fde7bcb209cd6
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-9587ed8f9c50c7d58b3f1ce60022278c/b5fe79a357db803b6d7bbb766b39189b
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpijz7t_cz/__LAZY_COLLECTIONS__/lazy_collection-bd0903c46dedb256829b818274ab0d75/cb0e4af162303630af808f79c590afc5
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:3.38 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__LAZY_COLLECTIONS__/lazy_collection-8781acad58711620dbad3a4e0ed9eab5/86ca6abe994ea855943bb7a105637b73
# 2021-08-23 06:03:47 INFO algoflow.core.serialize                  Saved bytes size:3.38 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__LAZY_COLLECTIONS__/lazy_collection-c5c3a3e67282d5f737d45b1a0352f210/47d7cdd6bce500e8a56e554aee06c3cc
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:3.38 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__LAZY_COLLECTIONS__/lazy_collection-0d8990c2b3ba3d246348d0dcd6ed9aee/3fd92d68ab37ae293cada83b52380bdd
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:14.69 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/feature_encoder_col_groups-1e3571c5/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:294.18 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/lazy_collection-65d8476b1a906d0bce1f53975689ba05/60d63014b86d18bb6598925d718a8516
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:7.93 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_lag to column Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_lag to column Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__SUCCESS__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:03:48 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/main_ts_col-5c3a34f7/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:48 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_std to column Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# ...
# 2021-08-23 06:03:49 INFO algoflow.core.serialize                  Saved bytes size:79.13 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-375ca3fa29b49c493836c332ee5dad81/f1097a36bda822179ca415b1ba4efc79
# 2021-08-23 06:03:49 INFO algoflow.core.serialize                  Saved bytes size:1.30 MB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-ee23a4420bec81d8ebb9647e32168f5d/783c552729a607f279f97f3263516e8b
# 2021-08-23 06:03:49 INFO algoflow.core.serialize                  Saved bytes size:79.13 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-6e1d90f0acfc12fbe595816165f097fb/1b337f19253f87b6fd01955f6d8fecba
# 2021-08-23 06:03:49 INFO algoflow.core.serialize                  Saved bytes size:79.13 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-66367f6e18172922343a2902a2d8a95d/8dd3596f41eb6e279fbfb7a0a2e76ae2
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Saved bytes size:1.70 MB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-17715bb845a7b299a770d84cd18f5432/51d7f5cac85a431575db6d8df20500e3
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Saved bytes size:71.91 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__SUCCESS__
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__SUCCESS__
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__TASK__
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model Starting ML model fit. (data=<algoflow.core.datamodel.Data object at 0x7f4c68b32950>, method_ind=lgb, param_opt_ind=random, param_space=None, score_func=None, tuning=False)
# 2021-08-23 06:03:50 WARNING algoflow.app.forecast.lib.model.ml_model Model fit parameter not specified, using default option
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model
#     Starting machine learning model training using
#     model = LGBMRegressor,
#     feature columns = ['cate1#categorizer#LabelEncoder()', 'cate2#categorizer#LabelEncoder()', 'cate3#categorizer#LabelEncoder()', 'date#time_feature~is_workday_CN#shift~0', 'date#time_feature~isoweekday#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_lag~size=14#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_lag~size=7#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=1#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=3#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=5#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=7#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=3#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=5#shift~0', 'sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=7#shift~0', 'stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=1#shift~0', 'stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=14#shift~0', 'stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=7#shift~0'],
#     encoded_categorical_columns = ['cate1#categorizer#LabelEncoder()', 'cate2#categorizer#LabelEncoder()', 'cate3#categorizer#LabelEncoder()'],
#     param_model ={'objective': 'tweedie', 'tweedie_variance_power': 1.4},
#     param_fit ={'eval_metric': 'l1'}
#
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-17715bb845a7b299a770d84cd18f5432/51d7f5cac85a431575db6d8df20500e3
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-17715bb845a7b299a770d84cd18f5432/51d7f5cac85a431575db6d8df20500e3
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-fit/train_data-0-7-f4fc6af6/__LAZY_COLLECTIONS__/lazy_collection-17715bb845a7b299a770d84cd18f5432/51d7f5cac85a431575db6d8df20500e3
# /usr/local/lib/python3.7/site-packages/lightgbm/basic.py:1551: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model LGB feature importance:
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_lag~size=14#shift~0: 285
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=1#shift~0: 256
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=14#shift~0: 244
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=5#shift~0: 232
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=3#shift~0: 222
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_lag~size=7#shift~0: 220
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_std~step=1~size=7#shift~0: 213
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=5#shift~0: 208
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=7#shift~0: 208
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=7#shift~0: 207
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False#partition_rolling_mean~step=1~size=3#shift~0: 195
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#partition_rolling_mean~step=1~size=1#shift~0: 186
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     cate3#categorizer#LabelEncoder(): 159
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     cate2#categorizer#LabelEncoder(): 83
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     date#time_feature~isoweekday#shift~0: 55
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     cate1#categorizer#LabelEncoder(): 18
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model     date#time_feature~is_workday_CN#shift~0: 9
# 2021-08-23 06:03:50 INFO algoflow.app.forecast.lib.model.ml_model
#         Finished ML model fit. param_fit = {'eval_metric': 'l1', 'categorical_feature': [0, 1, 2], 'method_ind': 'lgb'}
#
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Saved bytes size:351.60 kB as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__TASK__
# 2021-08-23 06:03:50 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__SUCCESS__
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# #015[                                        ] | 0% Completed |  0.0s#015[                                        ] | 0% Completed |  0.1s#015[                                        ] | 0% Completed |  0.2s#015[                                        ] | 0% Completed |  0.3s#015[                                        ] | 0% Completed |  0.4s#015[                                        ] | 0% Completed |  0.5s#015[                                        ] | 0% Completed |  0.6s#015[                                        ] | 0% Completed |  0.7s#015[                                        ] | 0% Completed |  0.8s#015[                                        ] | 0% Completed |  0.9s#015[                                        ] | 0% Completed |  1.0s#015[                                        ] | 0% Completed |  1.1s#015[                                        ] | 0% Completed |  1.2s#015[                                        ] | 0% Completed |  1.3s#015[                                        ] | 0% Completed |  1.4s#015[                                        ] | 0% Completed |  1.5s#015[                                        ] | 0% Completed |  1.6s#015[                                        ] | 0% Completed |  1.7s#015[                                        ] | 0% Completed |  1.8s#015[                                        ] | 0% Completed |  1.9s#015[                                        ] | 0% Completed |  2.0s#015[########################################] | 100% Completed |  2.1s#015#015[                                        ] | 0% Completed |  0.1s#015[###                                     ] | 9% Completed |  0.2s#015[####                                    ] | 11% Completed |  0.3s#015[#######                                 ] | 18% Completed |  0.4s#015[#########                               ] | 24% Completed |  0.5s#015[###########                             ] | 28% Completed |  0.6s#015[##############                          ] | 35% Completed |  0.7s#015[##############                          ] | 36% Completed |  0.8s#015[##############                          ] | 36% Completed |  1.0s#015[#################                       ] | 43% Completed |  1.1s#015[##################                      ] | 46% Completed |  1.2s#015[##################                      ] | 46% Completed |  1.3s#015[##################                      ] | 46% Completed |  1.4s#015[##################                      ] | 46% Completed |  1.5s#015[##################                      ] | 46% Completed |  1.6s#015[##################                      ] | 46% Completed |  1.7s#015[##################                      ] | 46% Completed |  1.8s#015[##################                      ] | 46% Completed |  1.9s#015[#######################                 ] | 58% Completed |  2.0s#015[###############################         ] | 78% Completed |  2.1s#015[#####################################   ] | 94% Completed |  2.2s#015[######################################  ] | 97% Completed |  2.3s#015[######################################  ] | 97% Completed |  2.4s#015[######################################  ] | 97% Completed |  2.5s#015[######################################  ] | 97% Completed |  2.6s#015[######################################  ] | 97% Completed |  2.7s#015[######################################  ] | 97% Completed |  2.8s#015[######################################  ] | 97% Completed |  2.9s#015[######################################  ] | 97% Completed |  3.0s#015[####################################### ] | 98% Completed |  3.1s#015[####################################### ] | 98% Completed |  3.2s#015[####################################### ] | 98% Completed |  3.3s#015[####################################### ] | 98% Completed |  3.4s#015[########################################] | 100% Completed |  3.5s#015Training complete.
#
# 2021-08-23 06:04:24 Uploading - Uploading generated training model
# 2021-08-23 06:04:24 Completed - Training job completed
# ProfilerReport-1629698359: NoIssuesFound
# Training seconds: 139
# Billable seconds: 139

# %%
# !aws s3 ls s3://{bucket}/byo-algoflow/output/ --recursive
# Out:
# 2021-08-22 13:11:59    4060749 byo-algoflow/output/sagemaker-algoflow-2021-08-22-20-11-28-318/model.tar.gz
# 2021-08-22 13:11:59        194 byo-algoflow/output/sagemaker-algoflow-2021-08-22-20-11-28-318/output.tar.gz
# 2021-08-22 17:59:33    4060736 byo-algoflow/output/sagemaker-algoflow-2021-08-23-00-59-02-005/model.tar.gz
# 2021-08-22 17:59:33        194 byo-algoflow/output/sagemaker-algoflow-2021-08-23-00-59-02-005/output.tar.gz
# 2021-08-22 22:55:01     159390 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/profiler-output/system/incremental/2021082305/1629697980.algo-1.json
# 2021-08-22 22:55:30     242034 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/profiler-output/system/incremental/2021082305/1629698040.algo-1.json
# 2021-08-22 22:55:30     118565 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/profiler-output/system/incremental/2021082305/1629698100.algo-1.json
# 2021-08-22 22:55:45     322349 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-report.html
# 2021-08-22 22:55:44     168695 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-report.ipynb
# 2021-08-22 22:55:41        191 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/BatchSize.json
# 2021-08-22 22:55:41        199 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/CPUBottleneck.json
# 2021-08-22 22:55:41        126 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/Dataloader.json
# 2021-08-22 22:55:41        127 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/GPUMemoryIncrease.json
# 2021-08-22 22:55:41        198 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/IOBottleneck.json
# 2021-08-22 22:55:41        119 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/LoadBalancing.json
# 2021-08-22 22:55:41        151 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/LowGPUUtilization.json
# 2021-08-22 22:55:41        179 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/MaxInitializationTime.json
# 2021-08-22 22:55:41        133 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# 2021-08-22 22:55:41        458 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/OverallSystemUsage.json
# 2021-08-22 22:55:41        156 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-51-07-457/rule-output/ProfilerReport-1629697867/profiler-output/profiler-reports/StepOutlier.json
# 2021-08-22 23:04:04    1906417 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/output/model.tar.gz
# 2021-08-22 23:04:07          0 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/framework/training_job_end.ts
# 2021-08-22 23:03:01      44334 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/system/incremental/2021082306/1629698460.algo-1.json
# 2021-08-22 23:03:01     241616 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/system/incremental/2021082306/1629698520.algo-1.json
# 2021-08-22 23:04:00     241810 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/system/incremental/2021082306/1629698580.algo-1.json
# 2021-08-22 23:04:01       4029 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/system/incremental/2021082306/1629698640.algo-1.json
# 2021-08-22 23:04:07          0 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/profiler-output/system/training_job_end.ts
# 2021-08-22 23:04:13     322354 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-report.html
# 2021-08-22 23:04:13     168701 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-report.ipynb
# 2021-08-22 23:04:09        191 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/BatchSize.json
# 2021-08-22 23:04:09        199 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/CPUBottleneck.json
# 2021-08-22 23:04:09        126 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/Dataloader.json
# 2021-08-22 23:04:09        127 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/GPUMemoryIncrease.json
# 2021-08-22 23:04:09        198 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/IOBottleneck.json
# 2021-08-22 23:04:09        119 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/LoadBalancing.json
# 2021-08-22 23:04:09        151 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/LowGPUUtilization.json
# 2021-08-22 23:04:09        179 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/MaxInitializationTime.json
# 2021-08-22 23:04:09        133 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/OverallFrameworkMetrics.json
# 2021-08-22 23:04:09        467 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/OverallSystemUsage.json
# 2021-08-22 23:04:09        156 byo-algoflow/output/sagemaker-algoflow-2021-08-23-05-59-19-830/rule-output/ProfilerReport-1629698359/profiler-output/profiler-reports/StepOutlier.json

# %%
# transformation

transform_output_folder = "batch-transform-output"
output_path = "s3://{}/byo-algoflow/{}".format(sess.default_bucket(), transform_output_folder)

transformer = algo.transformer(
    instance_count=1,
    instance_type="ml.m4.xlarge",
    output_path=output_path,
    assemble_with="Line",
    accept="application/json",
    strategy=None,
    max_concurrent_transforms=2,
)

# %%
sess.upload_data("../local_test/predict-payload.json", key_prefix=prefix)
# Out:
# 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/predict-payload.json'

# %%
# prepare the payload 


transformer.transform(
    "s3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/predict-payload.json",
    content_type="application/json", split_type=None,
)
transformer.wait()
# Out:
# ................................Starting the inference server with 1 workers.
# Starting the inference server with 1 workers.
# [2021-08-23 06:10:52 +0000] [9] [INFO] Starting gunicorn 20.1.0
# [2021-08-23 06:10:52 +0000] [9] [INFO] Listening at: unix:/tmp/gunicorn.sock (9)
# [2021-08-23 06:10:52 +0000] [9] [INFO] Using worker: sync
# [2021-08-23 06:10:52 +0000] [13] [INFO] Booting worker with pid: 13
# [2021-08-23 06:10:52 +0000] [9] [INFO] Starting gunicorn 20.1.0
# [2021-08-23 06:10:52 +0000] [9] [INFO] Listening at: unix:/tmp/gunicorn.sock (9)
# [2021-08-23 06:10:52 +0000] [9] [INFO] Using worker: sync
# [2021-08-23 06:10:52 +0000] [13] [INFO] Booting worker with pid: 13
# 169.254.255.130 - - [23/Aug/2021:06:10:57 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [23/Aug/2021:06:10:57 +0000] "GET /ping HTTP/1.1" 200 1 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [23/Aug/2021:06:10:57 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Start preparing data
# 2021-08-23 06:10:57 INFO algoflow.app.forecast.cli.run_forecast   Reading schema file from /tmp/tmp5wr0qrs0/schema.yaml ...
# 2021-08-23 06:10:57 INFO algoflow.app.forecast.cli.run_forecast   Scheduler address is not given, will use LocalCluster ...
# 169.254.255.130 - - [23/Aug/2021:06:10:57 +0000] "GET /execution-parameters HTTP/1.1" 404 2 "-" "Go-http-client/1.1"
# Start preparing data
# 2021-08-23 06:10:57 INFO algoflow.app.forecast.cli.run_forecast   Reading schema file from /tmp/tmp5wr0qrs0/schema.yaml ...
# 2021-08-23 06:10:57 INFO algoflow.app.forecast.cli.run_forecast   Scheduler address is not given, will use LocalCluster ...
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.cli.run_forecast   run_forecast with run_id=run_id_1629699059-dd18 workspace=~/.algoflow
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.automl.api         Starting data merge. (target_ts_file={'type': 'TARGET_TIME_SERIES', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/target_ts.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'time': 'date', 'values': [{'name': 'sales', 'type': 'num'}]}}, related_ts_files=[{'type': 'RELATED_TIME_SERIES', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/stock_ts.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'time': 'date', 'values': ['stock']}}], item_metadata_files=[{'type': 'ITEM_METADATA', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/cate_info.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'values': [{'name': 'cate1', 'type': 'str'}, {'name': 'cate2', 'type': 'str'}, {'name': 'cate3', 'type': 'str'}]}}], output_path=/tmp/tmpp_ag21xs, data_frequency=day)
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.cli.run_forecast   run_forecast with run_id=run_id_1629699059-dd18 workspace=~/.algoflow
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.automl.api         Starting data merge. (target_ts_file={'type': 'TARGET_TIME_SERIES', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/target_ts.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'time': 'date', 'values': [{'name': 'sales', 'type': 'num'}]}}, related_ts_files=[{'type': 'RELATED_TIME_SERIES', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/stock_ts.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'time': 'date', 'values': ['stock']}}], item_metadata_files=[{'type': 'ITEM_METADATA', 'path': 's3://sagemaker-us-west-2-932478379847/DEMO-convect-byo/cate_info.csv', 'format': 'csv', 'schema': {'key': ['item_id'], 'values': [{'name': 'cate1', 'type': 'str'}, {'name': 'cate2', 'type': 'str'}, {'name': 'cate3', 'type': 'str'}]}}], output_path=/tmp/tmpp_ag21xs, data_frequency=day)
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.automl.api         Tasks fired with client
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.cli.run_forecast   Converted dataset will be saved at: /tmp/tmpp_ag21xs
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.automl.api         Tasks fired with client
# 2021-08-23 06:10:59 INFO algoflow.app.forecast.cli.run_forecast   Converted dataset will be saved at: /tmp/tmpp_ag21xs
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load convert_raw_data_partition_cnt:4
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'sales'], dtype='object')
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load convert_raw_data_partition_cnt:4
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'sales'], dtype='object')
# 2021-08-23T06:10:57.801:[sagemaker logs]: MaxConcurrentTransforms=2, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'stock'], dtype='object')
# 2021-08-23 06:11:01 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'cate1', 'cate2', 'cate3'], dtype='object')
# 2021-08-23 06:11:01 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:11:00 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'date', 'stock'], dtype='object')
# 2021-08-23 06:11:01 INFO algoflow.app.forecast.lib.data_loader.load Data columns: Index(['item_id', 'cate1', 'cate2', 'cate3'], dtype='object')
# 2021-08-23 06:11:01 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Converting date series from long to compact format. (key_cols=['item_id'] dt_col=date)
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load min_max_date=[Timestamp('2018-01-01 00:00:00'), Timestamp('2018-12-26 00:00:00')]
# 2021-08-23 06:11:02 INFO algoflow.app.forecast.lib.data_loader.load Finished converting input data from long to compact format.
# 2021-08-23 06:11:04 INFO algoflow.app.forecast.lib.data_loader.load Estimated number of partitions: 1
# 2021-08-23 06:11:04 INFO algoflow.app.forecast.lib.data_loader.load Estimated number of partitions: 1
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  save data to /tmp/tmpp_ag21xs
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  save data to /tmp/tmpp_ag21xs
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:1.32 kB as pickle file to /tmp/tmpp_ag21xs/__TASK__
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:14.57 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c67509b6f40b567909416c31a97570bc/a394d64ac0f1a8f63e7fc1e0c2e7b77b
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-d52a7d07630aeb64f20767df88ac4e6d/4642095a316a60aea633c2ab0a0abc0a
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-80b7b18b86701f88e66e9dbad6181df9/e0cd85d0147f798d1f7d6517493122f6
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:600.73 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-013b1c333bd8fc7e8a6ba416cab641db/6362b0e7101e9db242bfa9346d2db5f3
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-fda229521c7812e16f9badc7ba194a09/3fab9f724e8d24aaffec6e00ba3f350d
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.72 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-1d5cbf3075fba124b923f3ae8560f215/157d62e08395b2b6c6cf9d549638b3f9
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c5af7e73e8e7742685fe7e83397a6c8b/28c7b36c83689495fe152416a1e22d0a
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:13.08 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /tmp/tmpp_ag21xs/__SUCCESS__
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:1.32 kB as pickle file to /tmp/tmpp_ag21xs/__TASK__
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:14.57 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c67509b6f40b567909416c31a97570bc/a394d64ac0f1a8f63e7fc1e0c2e7b77b
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-d52a7d07630aeb64f20767df88ac4e6d/4642095a316a60aea633c2ab0a0abc0a
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-80b7b18b86701f88e66e9dbad6181df9/e0cd85d0147f798d1f7d6517493122f6
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:600.73 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-013b1c333bd8fc7e8a6ba416cab641db/6362b0e7101e9db242bfa9346d2db5f3
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:294.09 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-fda229521c7812e16f9badc7ba194a09/3fab9f724e8d24aaffec6e00ba3f350d
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.72 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-1d5cbf3075fba124b923f3ae8560f215/157d62e08395b2b6c6cf9d549638b3f9
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:2.75 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c5af7e73e8e7742685fe7e83397a6c8b/28c7b36c83689495fe152416a1e22d0a
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:13.08 kB as pickle file to /tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:05 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /tmp/tmpp_ag21xs/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.api                        run transform with token=convect-transform
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Create Algo transform function. (dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform)
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__TASK__
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Loaded DAG from file /opt/ml/model/fit-run/__DAG__
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Create transform func with dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform, check_point_path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Start transform process
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631
# 2021-08-23 06:11:11 INFO algoflow.core.api                        run transform with token=convect-transform
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Create Algo transform function. (dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform)
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__DAG__/__TASK__
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Loaded DAG from file /opt/ml/model/fit-run/__DAG__
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Create transform func with dag_path=/opt/ml/model/fit-run/__DAG__, model_path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit, output_path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform, check_point_path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform
# 2021-08-23 06:11:11 INFO algoflow.core.api                        Start transform process
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf
# 2021-08-23 06:11:11 INFO algoflow.core.utils.utilities
#         N_Workers=4
#         N_Cores=4
#         CPU Use(%)=0.0%
#         Memory Use=228.91 MB
#         Bytes Stored=0 B
#
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.dag            Submit dag to worker: ('tcp://127.0.0.1:38233', {'cpu': [0.0], 'memory': [57044992], 'time': [1629699071.2932642], 'read_bytes': [0.0], 'write_bytes': [0.0], 'num_fds': [19], 'bytes_stored': [0]})
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2
# 2021-08-23 06:11:11 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__SUCCESS__
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.step           reference_obj exists, task will be loaded from reference obj:/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf
# 2021-08-23 06:11:11 INFO algoflow.core.utils.utilities
#         N_Workers=4
#         N_Cores=4
#         CPU Use(%)=0.0%
#         Memory Use=228.91 MB
#         Bytes Stored=0 B
#
# 2021-08-23 06:11:11 INFO algoflow.core.definitions.dag            Submit dag to worker: ('tcp://127.0.0.1:38233', {'cpu': [0.0], 'memory': [57044992], 'time': [1629699071.2932642], 'read_bytes': [0.0], 'write_bytes': [0.0], 'num_fds': [19], 'bytes_stored': [0]})
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  load data from /tmp/tmpp_ag21xs
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Saved bytes size:447 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column stock - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  load data from /tmp/tmpp_ag21xs
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Saved bytes size:447 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-e0a0118c25654655b1d0dd7e989f8fee/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column stock - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesImputerFlow_fit-682a36e31f6246a4883ee18c906168b9/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.imputer Applying column imputation on Column sales - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying column scaling on Column sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Saved bytes size:608 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__TASK__
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Saved bytes size:608 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/main_ts_col-5c3a34f7/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.feature.moving_window Applying rolling function partition_rolling_mean to column Column stock#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False - Type ColType.T_TIMESERIES - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/ml_model_fit-6950ca55ddf646f1af0d14148464eadf/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate1 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-b6e4d54c2e8e4993a9023f222345c3d6/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate1 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate2 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate1#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate2#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate3 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate3#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:820 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/feature_encoder_col_groups-1e3571c5/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c67509b6f40b567909416c31a97570bc/a394d64ac0f1a8f63e7fc1e0c2e7b77b
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:14.58 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:2.29 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.feature.time_feature Extracting time feature is_workday_CN from column Column date - Type ColType.T_TIMESTAMP - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.feature.time_feature Extracting time feature isoweekday from column Column date - Type ColType.T_TIMESTAMP - Role ColRole.R_FEATURE - use True
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__SUCCESS__
# 2021-08-23 06:11:13 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-a43b38e91b3b4232b0de08b2771743ce/__TASK__
# 2021-08-23 06:11:13 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate2 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c684c2d8f7942f1a87f61dce0ab44cd/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate1#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-31ab7e04a5b742b4a839538a9c147631/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate2#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/CategorizeFlow_fit-4531eeff68514fc8a3cdf573ac202389/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.categorizer Applying column categorization on Column cate3 - Type ColType.T_STR - Role ColRole.R_FEATURE - use True using Categorizer()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/AutoEncoderFlow_fit-2c3b4447c67d40ed9f33d678fc3bf4a2/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.preprocessor.encoder Applying column encoding on Column cate3#categorizer - Type ColType.T_CAT - Role ColRole.R_FEATURE - use True using LabelEncoder()
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:820 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/feature_encoder_col_groups-1e3571c5/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-c67509b6f40b567909416c31a97570bc/a394d64ac0f1a8f63e7fc1e0c2e7b77b
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:14.58 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/lazy_collection-e14eb72babd8bd3fe60bc964956d4790/0ac5344c750913f098ee5ddf73a091f8
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:2.29 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__SUCCESS__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__TASK__
# 2021-08-23 06:11:14 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/dt_col-65f424fc/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:14 INFO algoflow.app.forecast.lib.feature.time_feature Extracting time feature is_workday_CN from column Column date - Type ColType.T_TIMESTAMP - Role ColRole.R_FEATURE - use True
# ...
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:5.49 kB as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:2.86 kB as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.app.forecast.lib.preprocessor.scaler Applying inverse scaling on Column pred~lgb - Type ColType.T_NUM - Role ColRole.R_GEN - use True using Dask Series Structure:
# npartitions=1
# dummy_item_0     object
# dummy_item_99       ...
# Name: sales#SimpleImputer~missing_values=nan~strategy=median~fill_value=None~verbose=0~copy=True~add_indicator=False#MinMaxScaler~feature_range=(0, 1)~copy=True~clip=False, dtype: object
# Dask Name: rename, 1 tasks
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/tmp/tmpp_ag21xs/__LAZY_COLLECTIONS__/lazy_collection-1d5cbf3075fba124b923f3ae8560f215/157d62e08395b2b6c6cf9d549638b3f9
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__PERSIST__/model_id_convect-fit/TimeseriesScalerFlow_fit-fc0afe1df8c14a378d9cd40cb8046ae6/__LAZY_COLLECTIONS__/lazy_collection-2cec023c1aaf3235df548c780fa4816f/352f4b6a3da177564d48bbea1db5c068
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:5.49 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:12.29 kB as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:171 B as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__CHECK_POINT__/check_point_id_convect-transform/predict_sum_output-83959d2d/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:5.49 kB as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:2.86 kB as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.app.forecast.cli.run_forecast   Writing results to /tmp/tmpy_3svwxq ...
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Saved bytes size:176 B as pickle file to /opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.app.forecast.cli.run_forecast   Writing results to /tmp/tmpy_3svwxq ...
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__SUCCESS__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__TASK__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/__LAZY_COLLECTIONS_LOADER__
# 2021-08-23 06:11:18 INFO algoflow.core.serialize                  Read data from path=/opt/ml/model/fit-run/__OUTPUT__/output_id_convect-transform/predict_results/__LAZY_COLLECTIONS__/lazy_collection-f9fbad2715cfb9a5bf2565c4fee4b01e/3387134298c67b333dfc0db45b257293
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# distributed.nanny - WARNING - Worker process still alive after 3 seconds, killing
# #015[                                        ] | 0% Completed |  0.1s#015[                                        ] | 0% Completed |  0.2s#015[                                        ] | 0% Completed |  0.3s#015[                                        ] | 0% Completed |  0.4s#015[                                        ] | 0% Completed |  0.5s#015[                                        ] | 0% Completed |  0.6s#015[                                        ] | 0% Completed |  0.7s#015[                                        ] | 0% Completed |  0.8s#015[                                        ] | 0% Completed |  0.9s#015[                                        ] | 0% Completed |  1.0s#015[                                        ] | 0% Completed |  1.1s#015[                                        ] | 0% Completed |  1.2s#015[                                        ] | 0% Completed |  1.3s#015[######                                  ] | 17% Completed |  1.4s#015[######                                  ] | 17% Completed |  1.5s#015[######                                  ] | 17% Completed |  1.6s#015[######                                  ] | 17% Completed |  1.7s#015[######                                  ] | 17% Completed |  1.8s#015[######                                  ] | 17% Completed |  1.9s#015[######                                  ] | 17% Completed |  2.0s#015[#######                                 ] | 18% Completed |  2.1s#015[##########                              ] | 26% Completed |  2.2s#015[###########                             ] | 29% Completed |  2.3s#015[############                            ] | 31% Completed |  2.4s#015[#############                           ] | 32% Completed |  2.5s#015[#############                           ] | 32% Completed |  2.6s#015[#############                           ] | 32% Completed |  2.7s#015[#############                           ] | 32% Completed |  2.8s#015[#############                           ] | 32% Completed |  2.9s#015[#############                           ] | 32% Completed |  3.0s#015[#############                           ] | 32% Completed |  3.1s#015[##############                          ] | 36% Completed |  3.2s#015[##############                          ] | 36% Completed |  3.3s#015[################                        ] | 42% Completed |  3.4s#015[################                        ] | 42% Completed |  3.5s#015[################                        ] | 42% Completed |  3.6s#015[################                        ] | 42% Completed |  3.7s#015[################                        ] | 42% Completed |  3.8s#015[################                        ] | 42% Completed |  3.9s#015[##################                      ] | 44% Completed |  4.0s#015[######################                  ] | 56% Completed |  4.1s#015[########################                ] | 61% Completed |  4.2s#015[########################                ] | 61% Completed |  4.3s#015[########################                ] | 61% Completed |  4.4s#015[########################                ] | 61% Completed |  4.5s#015[########################                ] | 61% Completed |  4.6s#015[########################                ] | 61% Completed |  4.7s#015[########################                ] | 61% Completed |  4.8s#015[########################                ] | 61% Completed |  4.9s#015[###########################             ] | 69% Completed |  5.0s#015[##############################          ] | 77% Completed |  5.1s#015[###############################         ] | 79% Completed |  5.2s#015[###################################     ] | 88% Completed |  5.3s#015[####################################    ] | 92% Completed |  5.4s#015[####################################    ] | 92% Completed |  5.5s#015[####################################    ] | 92% Completed |  5.6s#015[####################################    ] | 92% Completed |  5.7s#015[################## ...
# 169.254.255.130 - - [23/Aug/2021:06:11:23 +0000] "POST /invocations HTTP/1.1" 200 5934 "-" "Go-http-client/1.1"
# #015[                                        ] | 0% Completed |  0.1s#015[                                        ] | 0% Completed |  0.2s#015[                                        ] | 0% Completed |  0.3s#015[                                        ] | 0% Completed |  0.4s#015[                                        ] | 0% Completed |  0.5s#015[                                        ] | 0% Completed |  0.6s#015[                                        ] | 0% Completed |  0.7s#015[                                        ] | 0% Completed |  0.8s#015[                                        ] | 0% Completed |  0.9s#015[                                        ] | 0% Completed |  1.0s#015[                                        ] | 0% Completed |  1.1s#015[                                        ] | 0% Completed |  1.2s#015[                                        ] | 0% Completed |  1.3s#015[######                                  ] | 17% Completed |  1.4s#015[######                                  ] | 17% Completed |  1.5s#015[######                                  ] | 17% Completed |  1.6s#015[######                                  ] | 17% Completed |  1.7s#015[######                                  ] | 17% Completed |  1.8s#015[######                                  ] | 17% Completed |  1.9s#015[######                                  ] | 17% Completed |  2.0s#015[#######                                 ] | 18% Completed |  2.1s#015[##########                              ] | 26% Completed |  2.2s#015[###########                             ] | 29% Completed |  2.3s#015[############                            ] | 31% Completed |  2.4s#015[#############                           ] | 32% Completed |  2.5s#015[#############                           ] | 32% Completed |  2.6s#015[#############                           ] | 32% Completed |  2.7s#015[#############                           ] | 32% Completed |  2.8s#015[#############                           ] | 32% Completed |  2.9s#015[#############                           ] | 32% Completed |  3.0s#015[#############                           ] | 32% Completed |  3.1s#015[##############                          ] | 36% Completed |  3.2s#015[##############                          ] | 36% Completed |  3.3s#015[################                        ] | 42% Completed |  3.4s#015[################                        ] | 42% Completed |  3.5s#015[################                        ] | 42% Completed |  3.6s#015[################                        ] | 42% Completed |  3.7s#015[################                        ] | 42% Completed |  3.8s#015[################                        ] | 42% Completed |  3.9s#015[##################                      ] | 44% Completed |  4.0s#015[######################                  ] | 56% Completed |  4.1s#015[########################                ] | 61% Completed |  4.2s#015[########################                ] | 61% Completed |  4.3s#015[########################                ] | 61% Completed |  4.4s#015[########################                ] | 61% Completed |  4.5s#015[########################                ] | 61% Completed |  4.6s#015[########################                ] | 61% Completed |  4.7s#015[########################                ] | 61% Completed |  4.8s#015[########################                ] | 61% Completed |  4.9s#015[###########################             ] | 69% Completed |  5.0s#015[##############################          ] | 77% Completed |  5.1s#015[###############################         ] | 79% Completed |  5.2s#015[###################################     ] | 88% Completed |  5.3s#015[####################################    ] | 92% Completed |  5.4s#015[####################################    ] | 92% Completed |  5.5s#015[####################################    ] | 92% Completed |  5.6s#015[####################################    ] | 92% Completed |  5.7s#015[################## ...
# 169.254.255.130 - - [23/Aug/2021:06:11:23 +0000] "POST /invocations HTTP/1.1" 200 5934 "-" "Go-http-client/1.1"

# %%
# !aws s3 ls {output_path} --recursive
# Out:
# 2021-08-22 23:11:24       5934 byo-algoflow/batch-transform-output/predict-payload.json.out
# 2021-08-22 18:07:39       5937 byo-algoflow/batch-transform-output/sagemaker-algoflow-2021-08-23-01-06-36-135/predict-payload.json.out

# %%
import pandas as pd

pd.read_csv("s3://{}/byo-algoflow/batch-transform-output/predict-payload.json.out".format(bucket)).head()
# Out:
#       Unnamed: 0        item_id  predict_sum predict_start_date  \
# 0   dummy_item_0   dummy_item_0   784.793026         2018-12-27
# 1   dummy_item_1   dummy_item_1   671.690725         2018-12-27
# 2  dummy_item_10  dummy_item_10   622.471802         2018-12-27
# 3  dummy_item_11  dummy_item_11   593.507004         2018-12-27
# 4  dummy_item_12  dummy_item_12   693.077343         2018-12-27
#
#    predict_horizon
# 0                7
# 1                7
# 2                7
# 3                7
# 4                7
